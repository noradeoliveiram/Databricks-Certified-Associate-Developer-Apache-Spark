# %%
from pyspark.sql import Row

# %%
import datetime

users = [
    {
        "id": 1,
        "first_name": "Corrie",
        "last_name": "Van der Oord",
        "email": "cvandenoor@etsy.com",
        "phone_numbers": Row(mobile="12345", home="67891"),
        "is_customer": True,
        "amount_paid": 1000.55,
        "customer_from": datetime.date(2021, 1, 15),
        "last_updated_ts": datetime.datetime(2021, 2, 10, 1, 15, 0)
    },
    {
        "id": 2,
        "first_name": "Nikolaus",
        "last_name": "Brewitt",
        "email": "nbrewitt@etsy.com",
        "phone_numbers": Row(mobile="3456", home="7890"),
        "is_customer": True,
        "amount_paid": 900.0,
        "customer_from": datetime.date(2021, 1, 14),
        "last_updated_ts": datetime.datetime(2021, 2, 18, 3, 33, 0)
    },
    {
        "id": 3,
        "first_name": "Orelie",
        "last_name": "Penney",
        "email": "openney@etsy.com",
        "phone_numbers": Row(mobile="0987", home="3215"),
        "is_customer": True,
        "amount_paid": 850.55,
        "customer_from": datetime.date(2021, 1, 21),
        "last_updated_ts": datetime.datetime(2021, 3, 15, 15, 16, 55)
    },
    {
        "id": 4,
        "first_name": "Ashby",
        "last_name": "Maddocks",
        "email": "amaddocks@etsy.com",
        "phone_numbers": Row(mobile=None, home=None),
        "is_customer": False,
        "amount_paid": None,
        "customer_from": None,
        "last_updated_ts": datetime.datetime(2021, 4, 10, 17, 45, 30)
    },
    {
        "id": 5,
        "first_name": "Kurt",
        "last_name": "Rome",
        "email": "krome@etsy.com",
        "phone_numbers": Row(mobile="56784", home=None),
        "email": "krome@etsy.com",
        "is_customer": False,
        "amount_paid": None,
        "customer_from": None,
        "last_updated_ts": datetime.datetime(2021, 4, 2, 0, 55, 18)
    }
]

# %%
from pyspark.sql.functions import explode, explode_outer

# %%
users_df = spark.createDataFrame([Row(**user) for user in users])

# %%
users_df.printSchema()

# %%
users_df.columns

# %%
users_df.dtypes

# %%
users_df.show()

# %%
users_df.select('id', 'phone_numbers').show(truncate=False)

# %%
users_df. \
    select('id', 'phone_numbers.mobile', 'phone_numbers.home'). \
    show()

# %%
users_df. \
    select('id', 'phone_numbers.*'). \
    show()

# %%
from pyspark.sql.functions import col

users_df. \
    select('id', col('phone_numbers')['mobile'], col('phone_numbers')['home']). \
    show()
