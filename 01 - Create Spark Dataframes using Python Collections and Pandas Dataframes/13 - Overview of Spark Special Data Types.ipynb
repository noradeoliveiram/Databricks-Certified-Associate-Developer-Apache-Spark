# %% [markdown]
# - Special types supported by Spark:
#   - Array
#   - Struct
#   - Map
#
# - Python structures such as List and Dict can be implicity converted to Spark Array and Map respectively.
# - We need to use few Spark related APIs to convert Python data structures to Sruct type.
