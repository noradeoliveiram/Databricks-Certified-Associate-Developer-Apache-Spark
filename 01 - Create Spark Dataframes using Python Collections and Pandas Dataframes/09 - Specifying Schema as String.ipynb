# %%
import datetime

users = [
    (1, "Corrie", "Van der Oord", "cvandenoor@etsy.com", True, 1000.55, datetime.date(2021, 1, 15), datetime.datetime(2021, 2, 10, 1, 15, 0)),
    (2, "Nikolaus", "Brewitt", "nbrewitt@etsy.com", True, 900.0, datetime.date(2021, 1, 14), datetime.datetime(2021, 2, 18, 3, 33, 0)),
    (3, "Orelie", "Penney", "openney@etsy.com", True, 850.55, datetime.date(2021, 1, 21), datetime.datetime(2021, 3, 15, 15, 16, 55)),
    (4, "Ashby", "Maddocks", "amaddocks@etsy.com", False, None, None, datetime.datetime(2021, 4, 10, 17, 45, 30)),
    (5, "Kurt", "Rome", "krome@etsy.com", False, None, None, datetime.datetime(2021, 4, 2, 0, 55, 18))
]

# %%
users_schema = '''
    id INT,
    first_name STRING,
    last_name STRING,
    email STRING,
    is_customer BOOLEAN,
    amount_paid FLOAT,
    customer_from DATE,
    last_updated_ts TIMESTAMP
'''

# %%
help(spark.createDataFrame)

# %%
spark.createDataFrame(users, schema=users_schema)

# %%
users_schema2 = '''
    id INT,
    first_name STRING,
    last_name STRING,
    email STRING,
    is_customer BOOLEAN,
    amount_paid FLOAT
'''

# %%
# Length mismatch: Expected axis has 6 element, new values have 8 elements.

# spark.createDataFrame(users, schema=users_schema2)

# %%
spark.createDataFrame(users, schema=users_schema).show()
