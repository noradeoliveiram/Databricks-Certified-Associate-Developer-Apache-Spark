# %%
users_list = [
    {'user_id': 1, 'user_first_name': 'Scott'},
    {'user_id': 2, 'user_first_name': 'Donald'},
    {'user_id': 3, 'user_first_name': 'Mickey'},
    {'user_id': 4, 'user_first_name': 'Elvis'}
]

# %%
df = spark.createDataFrame(users_list)

# %%
from pyspark.sql import Row

# %%
user_details = users_list[1]

# %%
type(user_details)

# %%
user_details

# %%
user_details.values()

# %%
Row(*user_details.values())

# %%
users_rows = [Row(*user.values()) for user in users_list]

# %%
users_rows

# %%
type(users_rows)

# %%
spark.createDataFrame(users_rows, 'user_id int, user_first_name string')

# %%
users_rows2 = [Row(**user) for user in users_list]

# %%
users_rows2

# %%
spark.createDataFrame(users_rows2)

# %%
def dummy(**kwargs):
    print(kwargs)
    print(len(kwargs))

# %%
user_details2 = {'user_id': 1, 'user_first_name': 'Scott'}

# %%
dummy(user_details2=user_details2)

# %%
dummy(user_id = 1, user_first_name = 'Scott')

# %%
dummy(**user_details2)
